# %%
name = input(prompt = "whats your name? ");
age = input(prompt = "how old are you");
print("Hello",name,"you are", age, "years old");
# Out:
# whats your name?  steve
# how old are you 12
# Hello steve you are  12 years old
